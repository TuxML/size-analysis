# %%
import pandas as pd
import json

with open("option_columns.json","r") as f:
    option_columns = json.load(f)

#Find the dataset
df = pd.read_csv("dataset_encoded_size.csv", dtype={k:"int8" for k in option_columns})

df.query("cid >= 30000", inplace=True)
df.fillna(-1, inplace=True)
df.query("kernel_size >= 0", inplace=True)

# %%
with open("optionsRelatedToSize.txt") as f:
    options_about_size = f.readlines()
options_about_size = [x.strip() for x in options_about_size] 
options_distr = pd.DataFrame(columns=["option", "val_0", "val_1", "val_2"])
i = 0
for o in options_about_size:
    vals = df[o].value_counts()
    nvals = vals.sum()
    print(o)
    val0 = 0
    val1 = 0
    val2 = 0
    for k, v in vals.iteritems():
        if (k == 0):
            val0 = v
        elif (k == 1):
            val1 = v
        elif (k == 2):
            val2 == v
        print(k, v, "(", (v / nvals) * 100, "%)")
    options_distr.loc[i] = (o, val0, val1, val2)
    i = i + 1
# Out:
# 8139TOO_8129
# 0 90670 ( 98.0502416921696 %)
# 1 1803 ( 1.949758307830394 %)
# ACENIC_OMIT_TIGON_I
# 0 90698 ( 98.08052080066614 %)
# 1 1775 ( 1.9194791993338596 %)
# ACPI
# 0 53631 ( 57.99638813491506 %)
# 1 38842 ( 42.00361186508494 %)
# ACPI_DEBUG
# 0 63424 ( 68.58650633157787 %)
# 1 29049 ( 31.41349366842213 %)
# ACPI_REDUCED_HARDWARE_ONLY
# 0 77695 ( 84.01911909422209 %)
# 1 14778 ( 15.980880905777903 %)
# ADVISE_SYSCALLS
# 1 57544 ( 62.227893547305705 %)
# 0 34929 ( 37.772106452694295 %)
# ATA_VERBOSE_ERROR
# 0 74106 ( 80.13798622300563 %)
# 1 18367 ( 19.862013776994367 %)
# ATH9K_DFS_CERTIFIED
# 0 92157 ( 99.65827863268197 %)
# 1 316 ( 0.341721367318028 %)
# ATM_FORE200E_DEBUG
# 0 92473 ( 100.0 %)
# B43LEGACY_DMA_MODE
# 0 92473 ( 100.0 %)
# B43LEGACY_PIO_MODE
# 0 92473 ( 100.0 %)
# BASE_FULL
# 1 57448 ( 62.12407946103187 %)
# 0 35025 ( 37.87592053896813 %)
# BATMAN_ADV_BLA
# 0 84949 ( 91.86357098828847 %)
# 1 7524 ( 8.136429011711527 %)
# BATMAN_ADV_DAT
# 0 85026 ( 91.94683853665394 %)
# 1 7447 ( 8.053161463346058 %)
# BATMAN_ADV_NC
# 0 77390 ( 83.68929309095627 %)
# 1 15083 ( 16.31070690904372 %)
# BINFMT_ELF
# 1 69592 ( 75.25656137467152 %)
# 0 22881 ( 24.743438625328473 %)
# BLK_DEV_INITRD
# 0 46304 ( 50.07299427941129 %)
# 1 46169 ( 49.92700572058871 %)
# BLK_DEV_RAM_DAX
# 0 87951 ( 95.10992397780974 %)
# 1 4522 ( 4.890076022190261 %)
# BRIDGE_IGMP_SNOOPING
# 0 85072 ( 91.99658278632683 %)
# 1 7401 ( 8.003417213673181 %)
# BRIDGE_VLAN_FILTERING
# 0 82547 ( 89.26605603797866 %)
# 1 9926 ( 10.733943962021348 %)
# BUG
# 1 73029 ( 78.97332194262108 %)
# 0 19444 ( 21.026678057378913 %)
# CAN_CALC_BITTIMING
# 0 82643 ( 89.36987012425249 %)
# 1 9830 ( 10.630129875747516 %)
# CAPI_TRACE
# 0 88395 ( 95.5900641268262 %)
# 1 4078 ( 4.409935873173791 %)
# CC_OPTIMIZE_FOR_SIZE
# 0 82075 ( 88.75563678046565 %)
# 1 10398 ( 11.244363219534351 %)
# CC_STACKPROTECTOR_REGULAR
# 0 92473 ( 100.0 %)
# CC_STACKPROTECTOR_STRONG
# 0 92473 ( 100.0 %)
# CEPH_LIB_PRETTYDEBUG
# 0 83358 ( 90.14306878764611 %)
# 1 9115 ( 9.856931212353876 %)
# CIFS_DEBUG
# 0 88879 ( 96.11346014512344 %)
# 1 3594 ( 3.8865398548765584 %)
# CIFS_DEBUG2
# 0 90672 ( 98.05240448563364 %)
# 1 1801 ( 1.9475955143663557 %)
# CPU_SUP_AMD
# 1 75087 ( 81.19883641711635 %)
# 0 17386 ( 18.801163582883653 %)
# CPU_SUP_CENTAUR
# 1 74999 ( 81.10367350469868 %)
# 0 17474 ( 18.89632649530133 %)
# CPU_SUP_CYRIX_32
# 0 92473 ( 100.0 %)
# CPU_SUP_INTEL
# 1 75065 ( 81.17504568901192 %)
# 0 17408 ( 18.824954310988073 %)
# CPU_SUP_TRANSMETA_32
# 0 92473 ( 100.0 %)
# CPU_SUP_UMC_32
# 0 92473 ( 100.0 %)
# DEBUG_INFO
# 0 83582 ( 90.3853016556184 %)
# 1 8891 ( 9.614698344381603 %)
# DEBUG_INFO_DWARF4
# 0 88050 ( 95.21698225427963 %)
# 1 4423 ( 4.783017745720373 %)
# DEBUG_INFO_REDUCED
# 0 88052 ( 95.21914504774367 %)
# 1 4421 ( 4.780854952256335 %)
# DEBUG_INFO_SPLIT
# 0 87994 ( 95.15642403728656 %)
# 1 4479 ( 4.843575962713441 %)
# DEBUG_SECTION_MISMATCH
# 0 46312 ( 50.08164545326744 %)
# 1 46161 ( 49.91835454673256 %)
# DEBUG_VM_VMACACHE
# 0 72165 ( 78.03899516615661 %)
# 1 20308 ( 21.961004833843393 %)
# DYNAMIC_DEBUG
# 0 64170 ( 69.3932282936641 %)
# 1 28303 ( 30.606771706335905 %)
# DYNAMIC_FTRACE
# 0 75342 ( 81.47459258378122 %)
# 1 17131 ( 18.52540741621879 %)
# EISA_NAMES
# 0 92473 ( 100.0 %)
# EXT4_USE_FOR_EXT2
# 0 83915 ( 90.74540676738076 %)
# 1 8558 ( 9.254593232619252 %)
# FAT_FS
# 1 42553 ( 46.016675137607734 %)
# 2 40410 ( 43.69924194089086 %)
# 0 9510 ( 10.284082921501412 %)
# FB_MODE_HELPERS
# 1 75678 ( 81.83794188573962 %)
# 0 16795 ( 18.16205811426038 %)
# FRAME_POINTER
# 1 85231 ( 92.16852486671785 %)
# 0 7242 ( 7.831475133282146 %)
# FS_DAX
# 0 64260 ( 69.49055399954581 %)
# 1 28213 ( 30.509446000454187 %)
# GCOV_PROFILE_ALL
# 0 86998 ( 94.07935289219556 %)
# 1 5475 ( 5.92064710780444 %)
# HIGH_RES_TIMERS
# 0 46470 ( 50.252506136926456 %)
# 1 46003 ( 49.747493863073544 %)
# HWSPINLOCK_SIRF
# 0 92473 ( 100.0 %)
# INET
# 0 70033 ( 75.73345733349194 %)
# 1 22440 ( 24.266542666508062 %)
# INITRAMFS_COMPRESSION_BZIP2
# 0 92473 ( 100.0 %)
# INITRAMFS_COMPRESSION_GZIP
# 0 92473 ( 100.0 %)
# INITRAMFS_COMPRESSION_LZ4
# 0 92473 ( 100.0 %)
# INITRAMFS_COMPRESSION_LZMA
# 0 92473 ( 100.0 %)
# INITRAMFS_COMPRESSION_LZO
# 0 92473 ( 100.0 %)
# INITRAMFS_COMPRESSION_NONE
# 0 92473 ( 100.0 %)
# INITRAMFS_COMPRESSION_XZ
# 0 92473 ( 100.0 %)
# IPW2100_DEBUG
# 0 91592 ( 99.04728947909119 %)
# 1 881 ( 0.9527105209088058 %)
# IPW2200_DEBUG
# 0 91614 ( 99.07108020719562 %)
# 1 859 ( 0.9289197928043861 %)
# IPX
# 1 62751 ( 67.85872633092903 %)
# 2 22261 ( 24.072972651476647 %)
# 0 7461 ( 8.068301017594324 %)
# IRQSOFF_TRACER
# 0 69529 ( 75.18843338055432 %)
# 1 22944 ( 24.811566619445678 %)
# ISDN_CAPI_CAPIDRV_VERBOSE
# 0 91143 ( 98.56174234641463 %)
# 1 1330 ( 1.4382576535853708 %)
# IWLEGACY_DEBUG
# 0 91675 ( 99.13704540784877 %)
# 1 798 ( 0.8629545921512225 %)
# IWLWIFI_DEBUG
# 0 91916 ( 99.39766202026537 %)
# 1 557 ( 0.6023379797346252 %)
# JUMP_LABEL
# 0 46269 ( 50.03514539379063 %)
# 1 46204 ( 49.96485460620938 %)
# KALLSYMS
# 1 92045 ( 99.53716219869584 %)
# 0 428 ( 0.46283780130416446 %)
# KALLSYMS_ALL
# 1 78742 ( 85.15134147264607 %)
# 0 13731 ( 14.84865852735393 %)
# KASAN_INLINE
# 0 92473 ( 100.0 %)
# KASAN_OUTLINE
# 0 81348 ( 87.96946135628778 %)
# 1 11125 ( 12.03053864371222 %)
# KERNEL_BZIP2
# 0 92473 ( 100.0 %)
# KERNEL_GZIP
# 0 92473 ( 100.0 %)
# KERNEL_LZ4
# 0 92473 ( 100.0 %)
# KERNEL_LZMA
# 0 92473 ( 100.0 %)
# KERNEL_LZO
# 0 92473 ( 100.0 %)
# KERNEL_XZ
# 0 92473 ( 100.0 %)
# LGUEST_GUEST
# 0 92473 ( 100.0 %)
# LIBIPW_DEBUG
# 0 91318 ( 98.75098677451797 %)
# 1 1155 ( 1.2490132254820325 %)
# MAC80211_MESSAGE_TRACING
# 0 86262 ( 93.28344489742952 %)
# 1 6211 ( 6.716555102570481 %)
# MAC80211_NOINLINE
# 0 89420 ( 96.69849577714577 %)
# 1 3053 ( 3.3015042228542386 %)
# MEDIA_SUBDRV_AUTOSELECT
# 0 63787 ( 68.97905334530078 %)
# 1 28686 ( 31.02094665469921 %)
# MINIX_FS
# 1 70055 ( 75.75724806159636 %)
# 2 16982 ( 18.364279303147946 %)
# 0 5436 ( 5.878472635255696 %)
# MODULE_COMPRESS
# 0 69561 ( 75.22303807597893 %)
# 1 22912 ( 24.776961924021066 %)
# MODULE_SIG
# 0 69316 ( 74.95809587663426 %)
# 1 23157 ( 25.04190412336574 %)
# MODULE_UNLOAD
# 0 69391 ( 75.03920063153569 %)
# 1 23082 ( 24.960799368464308 %)
# MSDOS_FS
# 1 55092 ( 59.57630876039492 %)
# 2 28047 ( 30.32993414293902 %)
# 0 9334 ( 10.093757096666053 %)
# MTD_CFI_ADV_OPTIONS
# 0 64274 ( 69.50569355379407 %)
# 1 28199 ( 30.494306446205922 %)
# MTD_CFI_GEOMETRY
# 0 78479 ( 84.86693413212505 %)
# 1 13994 ( 15.133065867874947 %)
# NOMMU_INITIAL_TRIM_EXCESS
# 0 92473 ( 100.0 %)
# OCFS2_DEBUG_MASKLOG
# 0 83434 ( 90.22525493927958 %)
# 1 9039 ( 9.774745060720425 %)
# OMAP_REMOTEPROC
# 0 92473 ( 100.0 %)
# OPENVSWITCH_GENEVE
# 1 90646 ( 98.02428817060115 %)
# 2 983 ( 1.0630129875747514 %)
# 0 844 ( 0.9126988418241 %)
# OPENVSWITCH_GRE
# 1 88170 ( 95.34674986212191 %)
# 2 2210 ( 2.3898867777621575 %)
# 0 2093 ( 2.263363360115926 %)
# OPENVSWITCH_VXLAN
# 1 90667 ( 98.04699750197355 %)
# 2 964 ( 1.0424664496663891 %)
# 0 842 ( 0.9105360483600617 %)
# OPTIMIZE_INLINING
# 1 51339 ( 55.51782682512734 %)
# 0 41134 ( 44.48217317487266 %)
# PLIP
# 1 81528 ( 88.16411276805121 %)
# 2 6828 ( 7.38377688622625 %)
# 0 4117 ( 4.452110345722535 %)
# PNP_DEBUG_MESSAGES
# 0 73042 ( 78.98738010013734 %)
# 1 19431 ( 21.012619899862663 %)
# POSIX_TIMERS
# 1 57451 ( 62.127323651227925 %)
# 0 35022 ( 37.872676348772075 %)
# PPP
# 1 74275 ( 80.32074227071686 %)
# 2 13373 ( 14.4615184972911 %)
# 0 4825 ( 5.2177392319920415 %)
# PREEMPT_TRACER
# 0 92473 ( 100.0 %)
# PROC_FS
# 1 57351 ( 62.019183978026014 %)
# 0 35122 ( 37.980816021973986 %)
# PROC_PAGE_MONITOR
# 1 46469 ( 50.25142474019444 %)
# 0 46004 ( 49.74857525980557 %)
# PROC_SYSCTL
# 0 52483 ( 56.75494468655716 %)
# 1 39990 ( 43.24505531344284 %)
# READABLE_ASM
# 0 51704 ( 55.9125366323143 %)
# 1 40769 ( 44.0874633676857 %)
# REISERFS_PROC_INFO
# 0 79563 ( 86.03916818963373 %)
# 1 12910 ( 13.960831810366269 %)
# SCSI_CONSTANTS
# 0 67815 ( 73.33491938187363 %)
# 1 24658 ( 26.665080618126375 %)
# SCSI_LOGGING
# 0 67575 ( 73.07538416618905 %)
# 1 24898 ( 26.92461583381095 %)
# SH_CPU_FREQ
# 0 92473 ( 100.0 %)
# SLIP
# 1 82171 ( 88.85945086673948 %)
# 2 7737 ( 8.36676651563159 %)
# 0 2565 ( 2.7737826176289295 %)
# SLOB
# 0 84620 ( 91.5077914634542 %)
# 1 7853 ( 8.492208536545801 %)
# SLUB_DEBUG
# 1 53269 ( 57.60492251792415 %)
# 0 39204 ( 42.39507748207585 %)
# SND_PROC_FS
# 0 75042 ( 81.15017356417549 %)
# 1 17431 ( 18.84982643582451 %)
# SSB_SILENT
# 0 68140 ( 73.68637331977983 %)
# 1 24333 ( 26.31362668022017 %)
# SUNRPC_DEBUG
# 0 91048 ( 98.45900965687282 %)
# 1 1425 ( 1.540990343127183 %)
# SYSCTL_SYSCALL
# 0 83780 ( 90.59941820855816 %)
# 1 8693 ( 9.400581791441827 %)
# SYSFS
# 1 92015 ( 99.50472029673526 %)
# 0 458 ( 0.49527970326473675 %)
# SYSTEM_EXTRA_CERTIFICATE
# 0 72423 ( 78.31799552301753 %)
# 1 20050 ( 21.68200447698247 %)
# SYSV_FS
# 1 70000 ( 75.6977712413353 %)
# 2 16798 ( 18.165302304456436 %)
# 0 5675 ( 6.136926454208255 %)
# THINKPAD_ACPI_DEBUG
# 0 83637 ( 90.44477847587945 %)
# 1 8836 ( 9.555221524120554 %)
# TRIM_UNUSED_KSYMS
# 0 81323 ( 87.94242643798731 %)
# 1 11150 ( 12.057573562012696 %)
# UBSAN_SANITIZE_ALL
# 0 86946 ( 94.02312026213056 %)
# 1 5527 ( 5.9768797378694325 %)
# UNUSED_SYMBOLS
# 1 46641 ( 50.43742497810172 %)
# 0 45832 ( 49.56257502189828 %)
# VFAT_FS
# 1 55217 ( 59.71148335189731 %)
# 2 27822 ( 30.08661987823473 %)
# 0 9434 ( 10.201896769867961 %)
# VIRTIO_PCI_LEGACY
# 0 74098 ( 80.12933504914949 %)
# 1 18375 ( 19.870664950850518 %)
# X86_FAST_FEATURE_TESTS
# 1 69074 ( 74.69639786748564 %)
# 0 23399 ( 25.303602132514357 %)
# X86_FEATURE_NAMES
# 1 80825 ( 87.40389086544181 %)
# 0 11648 ( 12.596109134558194 %)
# X86_INTEL_MPX
# 0 55050 ( 59.53089009765012 %)
# 1 37423 ( 40.46910990234988 %)
# X86_SMAP
# 1 57293 ( 61.95646296756892 %)
# 0 35180 ( 38.04353703243109 %)
# X86_VSYSCALL_EMULATION
# 1 57511 ( 62.192207455149074 %)
# 0 34962 ( 37.80779254485093 %)
# XEN_STUB
# 0 92473 ( 100.0 %)
# XFS_DEBUG
# 0 83167 ( 89.93652201183048 %)
# 1 9306 ( 10.06347798816952 %)

# %%
# TODO: you can plot the whole (20 here)
import matplotlib.pyplot as plt
fig = plt.figure()
ax = options_distr[:20].plot.bar(figsize=(20, 10))
ax.set_xticklabels(options_distr['option'].values)
plt.show()

# %%
options_distr
# Out:
#                          option  val_0  val_1 val_2
# 0                  8139TOO_8129  90670   1803     0
# 1           ACENIC_OMIT_TIGON_I  90698   1775     0
# 2                          ACPI  53631  38842     0
# 3                    ACPI_DEBUG  63424  29049     0
# 4    ACPI_REDUCED_HARDWARE_ONLY  77695  14778     0
# 5               ADVISE_SYSCALLS  34929  57544     0
# 6             ATA_VERBOSE_ERROR  74106  18367     0
# 7           ATH9K_DFS_CERTIFIED  92157    316     0
# 8            ATM_FORE200E_DEBUG  92473      0     0
# 9            B43LEGACY_DMA_MODE  92473      0     0
# 10           B43LEGACY_PIO_MODE  92473      0     0
# 11                    BASE_FULL  35025  57448     0
# 12               BATMAN_ADV_BLA  84949   7524     0
# 13               BATMAN_ADV_DAT  85026   7447     0
# 14                BATMAN_ADV_NC  77390  15083     0
# 15                   BINFMT_ELF  22881  69592     0
# 16               BLK_DEV_INITRD  46304  46169     0
# 17              BLK_DEV_RAM_DAX  87951   4522     0
# 18         BRIDGE_IGMP_SNOOPING  85072   7401     0
# 19        BRIDGE_VLAN_FILTERING  82547   9926     0
# 20                          BUG  19444  73029     0
# 21           CAN_CALC_BITTIMING  82643   9830     0
# 22                   CAPI_TRACE  88395   4078     0
# 23         CC_OPTIMIZE_FOR_SIZE  82075  10398     0
# 24    CC_STACKPROTECTOR_REGULAR  92473      0     0
# 25     CC_STACKPROTECTOR_STRONG  92473      0     0
# 26         CEPH_LIB_PRETTYDEBUG  83358   9115     0
# 27                   CIFS_DEBUG  88879   3594     0
# 28                  CIFS_DEBUG2  90672   1801     0
# 29                  CPU_SUP_AMD  17386  75087     0
# ..                          ...    ...    ...   ...
# 103           PROC_PAGE_MONITOR  46004  46469     0
# 104                 PROC_SYSCTL  52483  39990     0
# 105                READABLE_ASM  51704  40769     0
# 106          REISERFS_PROC_INFO  79563  12910     0
# 107              SCSI_CONSTANTS  67815  24658     0
# 108                SCSI_LOGGING  67575  24898     0
# 109                 SH_CPU_FREQ  92473      0     0
# 110                        SLIP   2565  82171     0
# 111                        SLOB  84620   7853     0
# 112                  SLUB_DEBUG  39204  53269     0
# 113                 SND_PROC_FS  75042  17431     0
# 114                  SSB_SILENT  68140  24333     0
# 115                SUNRPC_DEBUG  91048   1425     0
# 116              SYSCTL_SYSCALL  83780   8693     0
# 117                       SYSFS    458  92015     0
# 118    SYSTEM_EXTRA_CERTIFICATE  72423  20050     0
# 119                     SYSV_FS   5675  70000     0
# 120         THINKPAD_ACPI_DEBUG  83637   8836     0
# 121           TRIM_UNUSED_KSYMS  81323  11150     0
# 122          UBSAN_SANITIZE_ALL  86946   5527     0
# 123              UNUSED_SYMBOLS  45832  46641     0
# 124                     VFAT_FS   9434  55217     0
# 125           VIRTIO_PCI_LEGACY  74098  18375     0
# 126      X86_FAST_FEATURE_TESTS  23399  69074     0
# 127           X86_FEATURE_NAMES  11648  80825     0
# 128               X86_INTEL_MPX  55050  37423     0
# 129                    X86_SMAP  35180  57293     0
# 130      X86_VSYSCALL_EMULATION  34962  57511     0
# 131                    XEN_STUB  92473      0     0
# 132                   XFS_DEBUG  83167   9306     0
#
# [133 rows x 4 columns]
