# %%
import tuxml
import pandas as pd

df = tuxml.load_dataset()
df_options = pd.read_csv("dataOptionsText/comparison/feature_importanceRF/optionsInBoth.csv")
df_options.sort_values(by="Ranking")

freq = []
for o in df_options['option']:
    freq.append(df[o].value_counts(normalize=True)[0])
df_options["freq"] = freq
df_options
# Out:
#                          option  \
# 0                  8139TOO_8129
# 1           ACENIC_OMIT_TIGON_I
# 2                          ACPI
# 3                    ACPI_DEBUG
# 4    ACPI_REDUCED_HARDWARE_ONLY
# 5               ADVISE_SYSCALLS
# 6                           AIO
# 7             ATA_VERBOSE_ERROR
# 8           ATH9K_DFS_CERTIFIED
# 9                     BASE_FULL
# 10               BATMAN_ADV_BLA
# 11               BATMAN_ADV_DAT
# 12                BATMAN_ADV_NC
# 13                   BINFMT_ELF
# 14               BLK_DEV_INITRD
# 15              BLK_DEV_RAM_DAX
# 16         BRIDGE_IGMP_SNOOPING
# 17        BRIDGE_VLAN_FILTERING
# 18                          BUG
# 19           CAN_CALC_BITTIMING
# 20                   CAPI_TRACE
# 21         CC_OPTIMIZE_FOR_SIZE
# 22         CEPH_LIB_PRETTYDEBUG
# 23                   CIFS_DEBUG
# 24                  CIFS_DEBUG2
# 25                  CPU_SUP_AMD
# 26              CPU_SUP_CENTAUR
# 27                CPU_SUP_INTEL
# 28                   DEBUG_INFO
# 29            DEBUG_INFO_DWARF4
# ..                          ...
# 86           REISERFS_PROC_INFO
# 87                  RELOCATABLE
# 88               SCSI_CONSTANTS
# 89                 SCSI_LOGGING
# 90            SCSI_SAS_HOST_SMP
# 91              SERIAL_8250_PCI
# 92                 SKGE_GENESIS
# 93                         SLIP
# 94                         SLOB
# 95                   SLUB_DEBUG
# 96                  SND_PROC_FS
# 97                   SSB_SILENT
# 98                 SUNRPC_DEBUG
# 99               SYSCTL_SYSCALL
# 100                       SYSFS
# 101    SYSTEM_EXTRA_CERTIFICATE
# 102                     SYSV_FS
# 103         THINKPAD_ACPI_DEBUG
# 104           TRIM_UNUSED_KSYMS
# 105          UBSAN_SANITIZE_ALL
# 106              UNUSED_SYMBOLS
# 107                     VFAT_FS
# 108           VIRTIO_PCI_LEGACY
# 109                   X86_16BIT
# 110      X86_FAST_FEATURE_TESTS
# 111           X86_FEATURE_NAMES
# 112               X86_INTEL_MPX
# 113                    X86_SMAP
# 114      X86_VSYSCALL_EMULATION
# 115                   XFS_DEBUG
#
#                                                    url  Ranking  Unnamed: 3  \
# 0    https://cateee.net/lkddb/web-lkddb/8139TOO_812...     2165         NaN
# 1    https://cateee.net/lkddb/web-lkddb/ACENIC_OMIT...     7810         NaN
# 2         https://cateee.net/lkddb/web-lkddb/ACPI.html     3038         NaN
# 3    https://cateee.net/lkddb/web-lkddb/ACPI_DEBUG....     1418         NaN
# 4    https://cateee.net/lkddb/web-lkddb/ACPI_REDUCE...     2326         NaN
# 5    https://cateee.net/lkddb/web-lkddb/ADVISE_SYSC...     2271         NaN
# 6          https://cateee.net/lkddb/web-lkddb/AIO.html     2246         NaN
# 7    https://cateee.net/lkddb/web-lkddb/ATA_VERBOSE...     2485         NaN
# 8    https://cateee.net/lkddb/web-lkddb/ATH9K_DFS_C...     8864         NaN
# 9    https://cateee.net/lkddb/web-lkddb/BASE_FULL.html     1470         NaN
# 10   https://cateee.net/lkddb/web-lkddb/BATMAN_ADV_...     5447         NaN
# 11   https://cateee.net/lkddb/web-lkddb/BATMAN_ADV_...     5979         NaN
# 12   https://cateee.net/lkddb/web-lkddb/BATMAN_ADV_...      625         NaN
# 13   https://cateee.net/lkddb/web-lkddb/BINFMT_ELF....     5910         NaN
# 14   https://cateee.net/lkddb/web-lkddb/BLK_DEV_INI...     1149         NaN
# 15   https://cateee.net/lkddb/web-lkddb/BLK_DEV_RAM...     6968         NaN
# 16   https://cateee.net/lkddb/web-lkddb/BRIDGE_IGMP...     5526         NaN
# 17   https://cateee.net/lkddb/web-lkddb/BRIDGE_VLAN...     5594         NaN
# 18         https://cateee.net/lkddb/web-lkddb/BUG.html     5764         NaN
# 19   https://cateee.net/lkddb/web-lkddb/CAN_CALC_BI...     4766         NaN
# 20   https://cateee.net/lkddb/web-lkddb/CAPI_TRACE....     6428         NaN
# 21   https://cateee.net/lkddb/web-lkddb/CC_OPTIMIZE...      419         NaN
# 22   https://cateee.net/lkddb/web-lkddb/CEPH_LIB_PR...     4339         NaN
# 23   https://cateee.net/lkddb/web-lkddb/CIFS_DEBUG....     5740         NaN
# 24   https://cateee.net/lkddb/web-lkddb/CIFS_DEBUG2...     8735         NaN
# 25   https://cateee.net/lkddb/web-lkddb/CPU_SUP_AMD...     4187         NaN
# 26   https://cateee.net/lkddb/web-lkddb/CPU_SUP_CEN...     4023         NaN
# 27   https://cateee.net/lkddb/web-lkddb/CPU_SUP_INT...     4102         NaN
# 28   https://cateee.net/lkddb/web-lkddb/DEBUG_INFO....        1         NaN
# 29   https://cateee.net/lkddb/web-lkddb/DEBUG_INFO_...     4149         NaN
# ..                                                 ...      ...         ...
# 86   https://cateee.net/lkddb/web-lkddb/REISERFS_PR...     5159         NaN
# 87   https://cateee.net/lkddb/web-lkddb/RELOCATABLE...     4305         NaN
# 88   https://cateee.net/lkddb/web-lkddb/SCSI_CONSTA...     1588         NaN
# 89   https://cateee.net/lkddb/web-lkddb/SCSI_LOGGIN...     1853         NaN
# 90   https://cateee.net/lkddb/web-lkddb/SCSI_SAS_HO...      189         NaN
# 91   https://cateee.net/lkddb/web-lkddb/SERIAL_8250...     3475         NaN
# 92   https://cateee.net/lkddb/web-lkddb/SKGE_GENESI...     7969         NaN
# 93        https://cateee.net/lkddb/web-lkddb/SLIP.html      171         NaN
# 94        https://cateee.net/lkddb/web-lkddb/SLOB.html     4022         NaN
# 95   https://cateee.net/lkddb/web-lkddb/SLUB_DEBUG....     2279         NaN
# 96   https://cateee.net/lkddb/web-lkddb/SND_PROC_FS...     4142         NaN
# 97   https://cateee.net/lkddb/web-lkddb/SSB_SILENT....     1671         NaN
# 98   https://cateee.net/lkddb/web-lkddb/SUNRPC_DEBU...     8154         NaN
# 99   https://cateee.net/lkddb/web-lkddb/SYSCTL_SYSC...     7074         NaN
# 100      https://cateee.net/lkddb/web-lkddb/SYSFS.html     8629         NaN
# 101  https://cateee.net/lkddb/web-lkddb/SYSTEM_EXTR...     4443         NaN
# 102    https://cateee.net/lkddb/web-lkddb/SYSV_FS.html     2304         NaN
# 103  https://cateee.net/lkddb/web-lkddb/THINKPAD_AC...     5248         NaN
# 104  https://cateee.net/lkddb/web-lkddb/TRIM_UNUSED...     4764         NaN
# 105  https://cateee.net/lkddb/web-lkddb/UBSAN_SANIT...        7         NaN
# 106  https://cateee.net/lkddb/web-lkddb/UNUSED_SYMB...      553         NaN
# 107    https://cateee.net/lkddb/web-lkddb/VFAT_FS.html      248         NaN
# 108  https://cateee.net/lkddb/web-lkddb/VIRTIO_PCI_...     1065         NaN
# 109  https://cateee.net/lkddb/web-lkddb/X86_16BIT.html     2343         NaN
# 110  https://cateee.net/lkddb/web-lkddb/X86_FAST_FE...     3095         NaN
# 111  https://cateee.net/lkddb/web-lkddb/X86_FEATURE...     5075         NaN
# 112  https://cateee.net/lkddb/web-lkddb/X86_INTEL_M...     1043         NaN
# 113   https://cateee.net/lkddb/web-lkddb/X86_SMAP.html     1537         NaN
# 114  https://cateee.net/lkddb/web-lkddb/X86_VSYSCAL...     2491         NaN
# 115  https://cateee.net/lkddb/web-lkddb/XFS_DEBUG.html       14         NaN
#
#          freq
# 0    0.980502
# 1    0.980805
# 2    0.579966
# 3    0.685869
# 4    0.840199
# 5    0.377718
# 6    0.377708
# 7    0.801376
# 8    0.996583
# 9    0.378757
# 10   0.918634
# 11   0.919467
# 12   0.836900
# 13   0.247418
# 14   0.500719
# 15   0.951098
# 16   0.919964
# 17   0.892658
# 18   0.210250
# 19   0.893707
# 20   0.955900
# 21   0.887565
# 22   0.901429
# 23   0.961134
# 24   0.980524
# 25   0.188016
# 26   0.188967
# 27   0.188254
# 28   0.903862
# 29   0.952169
# ..        ...
# 86   0.860389
# 87   0.525743
# 88   0.733343
# 89   0.730748
# 90   0.794314
# 91   0.781607
# 92   0.980091
# 93   0.888603
# 94   0.915087
# 95   0.423949
# 96   0.811498
# 97   0.736869
# 98   0.984590
# 99   0.905992
# 100  0.004942
# 101  0.783175
# 102  0.756972
# 103  0.904446
# 104  0.879422
# 105  0.940230
# 106  0.495626
# 107  0.597106
# 108  0.801300
# 109  0.569919
# 110  0.253031
# 111  0.125942
# 112  0.595300
# 113  0.380422
# 114  0.378075
# 115  0.899363
#
# [116 rows x 5 columns]

# %%
# "GZIP" in df_options.columns
# Out:
# False
