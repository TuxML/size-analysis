# %%
import pandas as pd
import tuxml
import scipy.stats  

df = tuxml.load_dataset()
scipy.stats.ttest_ind(df.query("CC_OPTIMIZE_FOR_SIZE == 1")['vmlinux'], df.query("CC_OPTIMIZE_FOR_SIZE != 1")['vmlinux'])

sizes = ["vmlinux", "GZIP-bzImage", "GZIP-vmlinux", "GZIP", "BZIP2-bzImage", 
              "BZIP2-vmlinux", "BZIP2", "LZMA-bzImage", "LZMA-vmlinux", "LZMA", "XZ-bzImage", "XZ-vmlinux", "XZ", 
              "LZO-bzImage", "LZO-vmlinux", "LZO", "LZ4-bzImage", "LZ4-vmlinux", "LZ4"]
nbs = ['vmlinux', 'nbno', 'nbyes', 'nbmodule', 'nbyesmodule']
YES_VALUE = 1
# whether 'y' value has an effect
def ttest_option(ft_name):
    # return scipy.stats.ttest_ind(df.query(ft_name + " == 1")['vmlinux'], df.query(ft_name + " != 1")['vmlinux'])
    return scipy.stats.ttest_ind(df[df[ft_name] == 1]['vmlinux'], df[df[ft_name] != 1]['vmlinux'])

ttest_option("CC_OPTIMIZE_FOR_SIZE")

# proof of concept
r = {}
for o in df.columns:
    if o not in sizes and o not in "cid" and o not in nbs:
        print(o)
        r[o] = ttest_option(o).statistic
# Out:
# OPENVSWITCH
# TEXTSEARCH_FSM
# NETFILTER_XT_MATCH_TCPMSS
# MPLS
# NFC_HCI
# NETFILTER_XT_MATCH_TIME
# NET_MPLS_GSO
# NFC_SHDLC
# NETFILTER_XT_MATCH_U32
# OPENVSWITCH_GRE
# NFC_TRF7970A
# OPENVSWITCH_VXLAN
# NFC_MEI_PHY
# INTEL_MEI
# VXLAN
# IP_SET_BITMAP_IP
# OPENVSWITCH_GENEVE
# NFC_SIM
# GENERIC_IRQ_EFFECTIVE_AFF_MASK
# IP_SET_BITMAP_IPMAC
# GENEVE
# SMP
# IP_SET_BITMAP_PORT
# VSOCKETS
# NFC_PORT100
# GENERIC_IRQ_MIGRATION
# IP_SET_HASH_IP
# VMWARE_VMCI_VSOCKETS
# NFC_FDP
# IP_SET_HASH_IPMARK
# NFC_FDP_I2C
# VMWARE_VMCI
# IP_SET_HASH_IPPORT
# VIRTIO_VSOCKETS
# NFC_PN544
# GENERIC_PENDING_IRQ
# IP_SET_HASH_IPPORTIP
# VIRTIO_VSOCKETS_COMMON
# NFC_PN544_I2C
# NETLINK_DIAG
# NFC_PN544_MEI
# INTEL_IOMMU
# IP_SET_HASH_IPPORTNET
# MPLS_ROUTING
# NFC_PN533
# DMA_API_DEBUG
# IP_SET_HASH_IPMAC
# MPLS_IPTUNNEL
# NFC_PN533_USB
# IP_SET_HASH_MAC
# HSR
# NFC_PN533_I2C
# PATA_SERVERWORKS
# ATH9K_DYNACK
# SERIAL_FSL_LPUART_CONSOLE
# OMAP_WATCHDOG
# DVB_PLL
# CHROMEOS_LAPTOP
# STACK_TRACER
# ...

# %%
r
# Out:
# {'OPENVSWITCH': 23.634372468867166,
#  'TEXTSEARCH_FSM': 16.44682238252015,
#  'NETFILTER_XT_MATCH_TCPMSS': 13.015010561791183,
#  'MPLS': 17.981955731303557,
#  'NFC_HCI': 26.02430959419385,
#  'NETFILTER_XT_MATCH_TIME': 14.492075347126763,
#  'NET_MPLS_GSO': 23.693440722282215,
#  'NFC_SHDLC': 7.414621208522131,
#  'NETFILTER_XT_MATCH_U32': 12.832264026927584,
#  'OPENVSWITCH_GRE': 15.523718423326667,
#  'NFC_TRF7970A': 15.902760157345192,
#  'OPENVSWITCH_VXLAN': 11.159205839489521,
#  'NFC_MEI_PHY': 24.783154532095033,
#  'INTEL_MEI': 34.69614829675834,
#  'VXLAN': 14.15452103190346,
#  'IP_SET_BITMAP_IP': 16.245943574076957,
#  'OPENVSWITCH_GENEVE': 10.29930506345952,
#  'NFC_SIM': 24.734116097529117,
#  'GENERIC_IRQ_EFFECTIVE_AFF_MASK': 11.434381596335898,
#  'IP_SET_BITMAP_IPMAC': 14.378578048965817,
#  'GENEVE': 14.347743591546374,
#  'SMP': 11.434381596335898,
#  'IP_SET_BITMAP_PORT': 14.750202839975438,
#  'VSOCKETS': 24.256919575490063,
#  'NFC_PORT100': 18.17066256483946,
# ...

# %%
pd.Series(r).sort_values(ascending=True)
# Out:
# CLKSRC_MMIO           -65.181007
# COMPILE_TEST          -65.181007
# ROCKCHIP_GRF          -65.181007
# TIMER_OF              -65.076779
# TIMER_PROBE           -65.076779
# STMP_DEVICE           -59.822670
# STRICT_MODULE_RWX     -53.656772
# MODULES               -53.656772
# SOC_BUS               -49.571011
# MTK_INFRACFG          -49.500906
# RENESAS_DMA           -39.376576
# OWL_TIMER             -37.465353
# ASM9260_TIMER         -37.361896
# CLKSRC_PISTACHIO      -37.329205
# DIGICOLOR_TIMER       -37.324590
# PRIMA2_TIMER          -37.243170
# OXNAS_RPS_TIMER       -37.230030
# INTEGRATOR_AP_TIMER   -37.191664
# MTK_TIMER             -37.130289
# SH_TIMER_TMU          -37.080004
# CLKSRC_DBX500_PRCMU   -37.074308
# BCM2835_TIMER         -37.061016
# SH_TIMER_CMT          -37.052735
# ATMEL_ST              -37.046593
# MESON6_TIMER          -37.032886
# CLPS711X_TIMER        -37.006709
# VT8500_TIMER          -37.005322
# EM_TIMER_STI          -36.993630
# ...

# %%
# df.query("`8139CP` == 1") # backticks do not work for pandas < 0.25

# %%
scipy.stats.ttest_ind(df[df["DEBUG_INFO"] == 1]['vmlinux'], df[df["DEBUG_INFO"] != 1]['vmlinux'])
# Out:
# Ttest_indResult(statistic=213.4780959956709, pvalue=0.0)

# %%
pd.Series(r).sort_values().to_csv('ttest-features.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
