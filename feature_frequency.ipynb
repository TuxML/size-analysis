# %%
import tuxml 
import pandas as pd
df = tuxml.load_dataset()

# %%
with open("optionsRelatedToSize.txt") as f:
    options_about_size = f.readlines()
options_about_size = [x.strip() for x in options_about_size] 
options_distr = pd.DataFrame(columns=["option", "val_0", "val_1", "val_2"])
i = 0
for o in options_about_size:
    if o in df:
        vals = df[o].value_counts()
        nvals = vals.sum()
        print(o)
        val0 = 0
        val1 = 0
        val2 = 0
        for k, v in vals.iteritems():
            if (k == 0):
                val0 = v
            elif (k == 1):
                val1 = v
            elif (k == 2):
                val2 == v
            print(k, v, "(", (v / nvals) * 100, "%)")            
        options_distr.loc[i] = (o, val0, val1, val2)
    else:
        print(o, "missing")
        # obviously wrong (we don't know what's the unique value is!)
        options_distr.loc[i] = (o, 0, 0, 0)
    i = i + 1
# Out:
# 8139TOO_8129
# 0 90668 ( 98.0501995220123 %)
# 1 1803 ( 1.9498004779876934 %)
# ACENIC_OMIT_TIGON_I
# 0 90696 ( 98.08047928539759 %)
# 1 1775 ( 1.919520714602416 %)
# ACPI
# 0 53630 ( 57.99656108401553 %)
# 1 38841 ( 42.00343891598447 %)
# ACPI_DEBUG
# 0 63423 ( 68.58690832801635 %)
# 1 29048 ( 31.41309167198365 %)
# ACPI_REDUCED_HARDWARE_ONLY
# 0 77694 ( 84.01985487341977 %)
# 1 14777 ( 15.980145126580226 %)
# ADVISE_SYSCALLS
# 1 57543 ( 62.22815801710807 %)
# 0 34928 ( 37.771841982891935 %)
# AIO
# 1 57544 ( 62.22923943722897 %)
# 0 34927 ( 37.77076056277103 %)
# ATA_VERBOSE_ERROR
# 0 74104 ( 80.13755663937884 %)
# 1 18367 ( 19.862443360621167 %)
# ATH9K_DFS_CERTIFIED
# 0 92155 ( 99.65827124179472 %)
# 1 316 ( 0.34172875820527515 %)
# ATM_FORE200E_DEBUG missing
# B43LEGACY_DMA_MODE
# 0 92471 ( 100.0 %)
# B43LEGACY_PIO_MODE
# 0 92471 ( 100.0 %)
# BASE_FULL
# 1 57447 ( 62.124341685501406 %)
# 0 35024 ( 37.8756583144986 %)
# BATMAN_ADV_BLA
# 0 84947 ( 91.86339501032757 %)
# 1 7524 ( 8.136604989672438 %)
# BATMAN_ADV_DAT
# 0 85024 ( 91.94666435963708 %)
# 1 7447 ( 8.053335640362924 %)
# BATMAN_ADV_NC
# 0 77389 ( 83.69002173654442 %)
# 1 15082 ( 16.30997826345557 %)
# BINFMT_ELF
# 1 69592 ( 75.25818905386554 %)
# 0 22879 ( 24.741810946134464 %)
# BLK_DEV_INITRD
# 0 46302 ( 50.07191443804003 %)
# 1 46169 ( 49.92808556195997 %)
# BLK_DEV_RAM_DAX
# 0 87949 ( 95.10981821327768 %)
# 1 4522 ( 4.890181786722324 %)
# BRIDGE_IGMP_SNOOPING
# 0 85070 ( 91.9964096851986 %)
# 1 7401 ( 8.003590314801396 %)
# BRIDGE_VLAN_FILTERING
# 0 82545 ( 89.26582387991911 %)
# 1 9926 ( 10.73417612008089 %)
# BUG
# 1 73029 ( 78.97503000940836 %)
# 0 19442 ( 21.024969990591643 %)
# CAN_CALC_BITTIMING
# 0 82642 ( 89.37072163164667 %)
# 1 9829 ( 10.629278368353322 %)
# CAPI_TRACE
# 0 88393 ( 95.5899687469585 %)
# 1 4078 ( 4.4100312530414945 %)
# CC_OPTIMIZE_FOR_SIZE
# 0 82074 ( 88.7564750029739 %)
# 1 10397 ( 11.243524997026094 %)
# CC_STACKPROTECTOR_REGULAR
# 0 92471 ( 100.0 %)
# CC_STACKPROTECTOR_STRONG
# 0 92471 ( 100.0 %)
# CEPH_LIB_PRETTYDEBUG
# 0 83356 ( 90.14285559797126 %)
# 1 9115 ( 9.857144402028744 %)
# CIFS_DEBUG
# 0 88877 ( 96.11337608547544 %)
# 1 3594 ( 3.8866239145245536 %)
# CIFS_DEBUG2
# 0 90670 ( 98.05236236225412 %)
# 1 1801 ( 1.947637637745888 %)
# CPU_SUP_AMD
# 1 75085 ( 81.19842977798444 %)
# 0 17386 ( 18.801570222015553 %)
# CPU_SUP_CENTAUR
# 1 74997 ( 81.10326480734501 %)
# 0 17474 ( 18.896735192654994 %)
# CPU_SUP_CYRIX_32
# 0 92471 ( 100.0 %)
# CPU_SUP_INTEL
# 1 75063 ( 81.17463853532459 %)
# 0 17408 ( 18.82536146467541 %)
# CPU_SUP_TRANSMETA_32
# 0 92471 ( 100.0 %)
# CPU_SUP_UMC_32
# 0 92471 ( 100.0 %)
# DEBUG_INFO
# 0 83581 ( 90.38617512517439 %)
# 1 8890 ( 9.613824874825621 %)
# DEBUG_INFO_DWARF4
# 0 88048 ( 95.21687880524705 %)
# 1 4423 ( 4.78312119475295 %)
# DEBUG_INFO_REDUCED
# 0 88050 ( 95.21904164548886 %)
# 1 4421 ( 4.780958354511144 %)
# DEBUG_INFO_SPLIT
# 0 87993 ( 95.1574006985974 %)
# 1 4478 ( 4.842599301402601 %)
# DEBUG_PAGE_REF
# 0 72320 ( 78.2083031436883 %)
# 1 20151 ( 21.79169685631171 %)
# DEBUG_SECTION_MISMATCH
# 0 46310 ( 50.08056579900726 %)
# 1 46161 ( 49.91943420099275 %)
# DEBUG_VM_VMACACHE
# 0 72163 ( 78.03852018470656 %)
# 1 20308 ( 21.961479815293444 %)
# DOUBLEFAULT
# 1 57563 ( 62.24978641952612 %)
# 0 34908 ( 37.75021358047388 %)
# DYNAMIC_DEBUG
# 0 64168 ( 69.39256631808891 %)
# 1 28303 ( 30.607433681911083 %)
# DYNAMIC_FTRACE
# 0 75340 ( 81.47419190881465 %)
# 1 17131 ( 18.525808091185343 %)
# EISA_NAMES
# 0 92471 ( 100.0 %)
# ELF_CORE
# 0 52505 ( 56.77996344799992 %)
# 1 39966 ( 43.22003655200008 %)
# EXT4_USE_FOR_EXT2
# 0 83913 ( 90.7452066053141 %)
# 1 8558 ( 9.254793394685903 %)
# FAT_FS
# 0 42551 ( 46.01550756453375 %)
# 1 40410 ( 43.700187085680916 %)
# 2 9510 ( 10.284305349785338 %)
# FB_MODE_HELPERS
# 1 75677 ( 81.83863048955888 %)
# 0 16794 ( 18.161369510441112 %)
# FILE_LOCKING
# 1 57342 ( 62.01079257280661 %)
# 0 35129 ( 37.98920742719339 %)
# FRAME_POINTER
# 1 85230 ( 92.16943690454305 %)
# 0 7241 ( 7.830563095456953 %)
# FS_DAX
# 0 64258 ( 69.48989412897016 %)
# 1 28213 ( 30.510105871029836 %)
# GCOV_PROFILE_ALL
# 0 86996 ( 94.07922483805734 %)
# 1 5475 ( 5.920775161942663 %)
# HIGH_RES_TIMERS
# 0 46469 ( 50.2525115982308 %)
# 1 46002 ( 49.7474884017692 %)
# HWSPINLOCK_SIRF
# 0 92471 ( 100.0 %)
# INET
# 0 70031 ( 75.73293248694185 %)
# 1 22440 ( 24.267067513058148 %)
# INITRAMFS_COMPRESSION_BZIP2
# 0 92471 ( 100.0 %)
# INITRAMFS_COMPRESSION_GZIP
# 0 92471 ( 100.0 %)
# INITRAMFS_COMPRESSION_LZ4
# 0 92471 ( 100.0 %)
# INITRAMFS_COMPRESSION_LZMA
# 0 92471 ( 100.0 %)
# INITRAMFS_COMPRESSION_LZO
# 0 92471 ( 100.0 %)
# INITRAMFS_COMPRESSION_NONE
# 0 92471 ( 100.0 %)
# INITRAMFS_COMPRESSION_XZ
# 0 92471 ( 100.0 %)
# IP_MULTICAST
# 0 81328 ( 87.94973559278044 %)
# 1 11143 ( 12.05026440721956 %)
# IPW2100_DEBUG
# 0 91590 ( 99.04726887348467 %)
# 1 881 ( 0.95273112651534 %)
# IPW2200_DEBUG
# 0 91612 ( 99.07106011614452 %)
# 1 859 ( 0.9289398838554791 %)
# IPX
# 0 62750 ( 67.85911258664879 %)
# 1 22260 ( 24.07241189129565 %)
# 2 7461 ( 8.068475522055564 %)
# IRQSOFF_TRACER
# 0 69527 ( 75.18789674600686 %)
# 1 22944 ( 24.812103253993143 %)
# ISDN_CAPI_CAPIDRV_VERBOSE
# 0 91141 ( 98.56171123919931 %)
# 1 1330 ( 1.4382887608006834 %)
# ISO9660_FS
# 0 55206 ( 59.7008791945583 %)
# 1 27883 ( 30.153237231131925 %)
# 2 9382 ( 10.145883574309783 %)
# IWLEGACY_DEBUG
# 0 91673 ( 99.13702674351958 %)
# 1 798 ( 0.86297325648041 %)
# IWLWIFI_DEBUG
# 0 91914 ( 99.39764899265717 %)
# 1 557 ( 0.6023510073428426 %)
# JUMP_LABEL
# 0 46267 ( 50.034064733808435 %)
# 1 46204 ( 49.965935266191565 %)
# KALLSYMS
# 1 92044 ( 99.53823360837451 %)
# 0 427 ( 0.46176639162548255 %)
# KALLSYMS_ALL
# 1 78741 ( 85.15210174000497 %)
# 0 13730 ( 14.847898259995027 %)
# KASAN_INLINE
# 0 92471 ( 100.0 %)
# KASAN_OUTLINE
# 0 81346 ( 87.96920115495669 %)
# 1 11125 ( 12.03079884504331 %)
# KERNEL_BZIP2
# 0 92471 ( 100.0 %)
# KERNEL_GZIP
# 0 92471 ( 100.0 %)
# KERNEL_LZ4
# 1 92471 ( 100.0 %)
# KERNEL_LZMA
# 0 92471 ( 100.0 %)
# KERNEL_LZO
# 0 92471 ( 100.0 %)
# KERNEL_XZ
# 0 92471 ( 100.0 %)
# LGUEST_GUEST
# 0 92471 ( 100.0 %)
# LIBIPW_DEBUG
# 0 91316 ( 98.7509597603573 %)
# 1 1155 ( 1.2490402396426987 %)
# MAC80211_MESSAGE_TRACING
# 0 86261 ( 93.2843810491938 %)
# 1 6210 ( 6.715618950806198 %)
# MAC80211_NOINLINE
# 0 89419 ( 96.69950579100475 %)
# 1 3052 ( 3.3004942089952527 %)
# MATH_EMULATION
# 0 92471 ( 100.0 %)
# MEDIA_SUBDRV_AUTOSELECT
# 0 63785 ( 68.97838241178316 %)
# 1 28686 ( 31.02161758821685 %)
# MINIX_FS
# 0 70053 ( 75.75672372960172 %)
# 1 16982 ( 18.36467649317083 %)
# 2 5436 ( 5.878599777227455 %)
# MODULE_COMPRESS
# 0 69560 ( 75.22358360999665 %)
# 1 22911 ( 24.77641639000335 %)
# MODULE_SIG
# 0 69314 ( 74.95755426025457 %)
# 1 23157 ( 25.042445739745432 %)
# MODULE_UNLOAD
# 0 69389 ( 75.03866076932228 %)
# 1 23082 ( 24.961339230677726 %)
# MSDOS_FS
# 0 55090 ( 59.57543446053357 %)
# 1 28047 ( 30.330590130959976 %)
# 2 9334 ( 10.09397540850645 %)
# MTD_CFI_ADV_OPTIONS
# 0 64272 ( 69.5050340106628 %)
# 1 28199 ( 30.494965989337196 %)
# MTD_CFI_GEOMETRY
# 0 78477 ( 84.86660682808665 %)
# 1 13994 ( 15.133393171913356 %)
# MTRR
# 1 57439 ( 62.11569032453418 %)
# 0 35032 ( 37.88430967546582 %)
# NOMMU_INITIAL_TRIM_EXCESS missing
# OCFS2_DEBUG_MASKLOG
# 0 83432 ( 90.22504352715987 %)
# 1 9039 ( 9.774956472840133 %)
# OMAP_REMOTEPROC
# 0 92471 ( 100.0 %)
# OPENVSWITCH_GENEVE
# 0 90644 ( 98.02424543911063 %)
# 1 983 ( 1.0630359788474224 %)
# 2 844 ( 0.9127185820419375 %)
# OPENVSWITCH_GRE
# 0 88168 ( 95.34664921975539 %)
# 1 2210 ( 2.3899384671951207 %)
# 2 2093 ( 2.2634123130494963 %)
# OPENVSWITCH_VXLAN
# 0 90665 ( 98.0469552616496 %)
# 1 964 ( 1.04248899655027 %)
# 2 842 ( 0.910555741800132 %)
# OPTIMIZE_INLINING
# 1 51337 ( 55.51686474678548 %)
# 0 41134 ( 44.48313525321452 %)
# PLIP
# 0 81527 ( 88.1649381968401 %)
# 1 6828 ( 7.38393658552411 %)
# 2 4116 ( 4.451125217635799 %)
# PNP_DEBUG_MESSAGES
# 0 73040 ( 78.98692563073828 %)
# 1 19431 ( 21.013074369261712 %)
# POSIX_TIMERS
# 1 57451 ( 62.12866736598501 %)
# 0 35020 ( 37.87133263401499 %)
# PPP
# 0 74274 ( 80.3213980599323 %)
# 1 13373 ( 14.461831276832736 %)
# 2 4824 ( 5.216770663234961 %)
# PREEMPT_TRACER
# 0 92471 ( 100.0 %)
# PROC_FS
# 1 57351 ( 62.02052535389474 %)
# 0 35120 ( 37.97947464610527 %)
# PROC_PAGE_MONITOR
# 1 46469 ( 50.2525115982308 %)
# 0 46002 ( 49.7474884017692 %)
# PROC_SYSCTL
# 0 52481 ( 56.75400936509825 %)
# 1 39990 ( 43.24599063490175 %)
# READABLE_ASM
# 0 51703 ( 55.91266451103589 %)
# 1 40768 ( 44.08733548896411 %)
# REISERFS_PROC_INFO
# 0 79561 ( 86.03886623914525 %)
# 1 12910 ( 13.961133760854755 %)
# RELOCATABLE
# 0 48616 ( 52.57432059780904 %)
# 1 43855 ( 47.42567940219096 %)
# SCSI_CONSTANTS
# 0 67813 ( 73.3343426587795 %)
# 1 24658 ( 26.665657341220488 %)
# SCSI_LOGGING
# 0 67573 ( 73.07480182976285 %)
# 1 24898 ( 26.92519817023716 %)
# SCSI_SAS_HOST_SMP
# 0 73451 ( 79.43138930042932 %)
# 1 19020 ( 20.568610699570677 %)
# SERIAL_8250_PCI
# 0 72276 ( 78.16072065836856 %)
# 1 13297 ( 14.379643347644125 %)
# 2 6898 ( 7.4596359939873045 %)
# SH_CPU_FREQ
# 0 92471 ( 100.0 %)
# SKGE_GENESIS
# 0 90630 ( 98.009105557418 %)
# 1 1841 ( 1.9908944425819988 %)
# SLIP
# 0 82170 ( 88.86029133458058 %)
# 1 7736 ( 8.365866055303824 %)
# 2 2565 ( 2.773842610115604 %)
# SLOB
# 0 84619 ( 91.50868921067146 %)
# 1 7852 ( 8.491310789328546 %)
# SLUB_DEBUG
# 1 53268 ( 57.60508700024872 %)
# 0 39203 ( 42.39491299975127 %)
# SND_PROC_FS
# 0 75040 ( 81.14976587254382 %)
# 1 17431 ( 18.850234127456176 %)
# SSB_SILENT
# 0 68139 ( 73.68688561819381 %)
# 1 24332 ( 26.313114381806184 %)
# SUNRPC_DEBUG
# 0 91046 ( 98.45897632771356 %)
# 1 1425 ( 1.5410236722864465 %)
# SYSCTL_SYSCALL
# 0 83778 ( 90.59921488899224 %)
# 1 8693 ( 9.400785111007776 %)
# SYSFS
# 1 92014 ( 99.50579100474744 %)
# 0 457 ( 0.4942089952525657 %)
# SYSTEM_EXTRA_CERTIFICATE
# 0 72421 ( 78.31752657589948 %)
# 1 20050 ( 21.68247342410053 %)
# SYSV_FS
# 0 69998 ( 75.69724562295205 %)
# 1 16798 ( 18.165695190924723 %)
# 2 5675 ( 6.137059186123217 %)
# THINKPAD_ACPI_DEBUG
# 0 83635 ( 90.44457181170313 %)
# 1 8836 ( 9.555428188296872 %)
# TRIM_UNUSED_KSYMS
# 0 81321 ( 87.94216565193412 %)
# 1 11150 ( 12.05783434806588 %)
# UBSAN_SANITIZE_ALL
# 0 86944 ( 94.0229909917704 %)
# 1 5527 ( 5.977009008229607 %)
# UNUSED_SYMBOLS
# 1 46640 ( 50.43743443890517 %)
# 0 45831 ( 49.56256556109483 %)
# VFAT_FS
# 0 55215 ( 59.71061197564642 %)
# 1 27822 ( 30.087270603756856 %)
# 2 9434 ( 10.202117420596728 %)
# VIRTIO_PCI_LEGACY
# 0 74097 ( 80.12998669853252 %)
# 1 18374 ( 19.870013301467488 %)
# X86_16BIT
# 0 52701 ( 56.99192179169685 %)
# 1 39770 ( 43.00807820830314 %)
# X86_FAST_FEATURE_TESTS
# 1 69073 ( 74.696932011117 %)
# 0 23398 ( 25.303067988883 %)
# X86_FEATURE_NAMES
# 1 80825 ( 87.40578127196635 %)
# 0 11646 ( 12.594218728033654 %)
# X86_INTEL_MPX
# 0 55048 ( 59.53001481545566 %)
# 1 37423 ( 40.46998518454434 %)
# X86_SMAP
# 1 57293 ( 61.95780298688237 %)
# 0 35178 ( 38.04219701311762 %)
# X86_VSYSCALL_EMULATION
# 1 57510 ( 62.19247115311828 %)
# 0 34961 ( 37.80752884688173 %)
# XEN_STUB
# 0 92471 ( 100.0 %)
# XFS_DEBUG
# 0 83165 ( 89.93630435487883 %)
# 1 9306 ( 10.063695645121173 %)

# %%
# TODO: you can plot the whole (20 here)
import matplotlib.pyplot as plt
fig = plt.figure()
ax = options_distr[:20].plot.bar(figsize=(20, 10))
ax.set_xticklabels(options_distr['option'].values)
plt.show()

# %%
options_distr
# Out:
#                          option  val_0  val_1 val_2
# 0                  8139TOO_8129  90668   1803     0
# 1           ACENIC_OMIT_TIGON_I  90696   1775     0
# 2                          ACPI  53630  38841     0
# 3                    ACPI_DEBUG  63423  29048     0
# 4    ACPI_REDUCED_HARDWARE_ONLY  77694  14777     0
# 5               ADVISE_SYSCALLS  34928  57543     0
# 6                           AIO  34927  57544     0
# 7             ATA_VERBOSE_ERROR  74104  18367     0
# 8           ATH9K_DFS_CERTIFIED  92155    316     0
# 9            ATM_FORE200E_DEBUG      0      0     0
# 10           B43LEGACY_DMA_MODE  92471      0     0
# 11           B43LEGACY_PIO_MODE  92471      0     0
# 12                    BASE_FULL  35024  57447     0
# 13               BATMAN_ADV_BLA  84947   7524     0
# 14               BATMAN_ADV_DAT  85024   7447     0
# 15                BATMAN_ADV_NC  77389  15082     0
# 16                   BINFMT_ELF  22879  69592     0
# 17               BLK_DEV_INITRD  46302  46169     0
# 18              BLK_DEV_RAM_DAX  87949   4522     0
# 19         BRIDGE_IGMP_SNOOPING  85070   7401     0
# 20        BRIDGE_VLAN_FILTERING  82545   9926     0
# 21                          BUG  19442  73029     0
# 22           CAN_CALC_BITTIMING  82642   9829     0
# 23                   CAPI_TRACE  88393   4078     0
# 24         CC_OPTIMIZE_FOR_SIZE  82074  10397     0
# 25    CC_STACKPROTECTOR_REGULAR  92471      0     0
# 26     CC_STACKPROTECTOR_STRONG  92471      0     0
# 27         CEPH_LIB_PRETTYDEBUG  83356   9115     0
# 28                   CIFS_DEBUG  88877   3594     0
# 29                  CIFS_DEBUG2  90670   1801     0
# ..                          ...    ...    ...   ...
# 117              SCSI_CONSTANTS  67813  24658     0
# 118                SCSI_LOGGING  67573  24898     0
# 119           SCSI_SAS_HOST_SMP  73451  19020     0
# 120             SERIAL_8250_PCI  72276  13297     0
# 121                 SH_CPU_FREQ  92471      0     0
# 122                SKGE_GENESIS  90630   1841     0
# 123                        SLIP  82170   7736     0
# 124                        SLOB  84619   7852     0
# 125                  SLUB_DEBUG  39203  53268     0
# 126                 SND_PROC_FS  75040  17431     0
# 127                  SSB_SILENT  68139  24332     0
# 128                SUNRPC_DEBUG  91046   1425     0
# 129              SYSCTL_SYSCALL  83778   8693     0
# 130                       SYSFS    457  92014     0
# 131    SYSTEM_EXTRA_CERTIFICATE  72421  20050     0
# 132                     SYSV_FS  69998  16798     0
# 133         THINKPAD_ACPI_DEBUG  83635   8836     0
# 134           TRIM_UNUSED_KSYMS  81321  11150     0
# 135          UBSAN_SANITIZE_ALL  86944   5527     0
# 136              UNUSED_SYMBOLS  45831  46640     0
# 137                     VFAT_FS  55215  27822     0
# 138           VIRTIO_PCI_LEGACY  74097  18374     0
# 139                   X86_16BIT  52701  39770     0
# 140      X86_FAST_FEATURE_TESTS  23398  69073     0
# 141           X86_FEATURE_NAMES  11646  80825     0
# 142               X86_INTEL_MPX  55048  37423     0
# 143                    X86_SMAP  35178  57293     0
# 144      X86_VSYSCALL_EMULATION  34961  57510     0
# 145                    XEN_STUB  92471      0     0
# 146                   XFS_DEBUG  83165   9306     0
#
# [147 rows x 4 columns]
